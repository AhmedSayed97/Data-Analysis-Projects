# %%
# import libraries

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
from matplotlib.pyplot import figure
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)  # Adjust the configuration of the plots we will create

# %%
# Read in Data

df = pd.read_csv(r'E:\Courses\Data Analyst Portfolio Projects\movies.csv')
df
# Out:
#                                                 name      genre  year  \
# 0                                        The Shining      Drama  1980
# 1                                    The Blue Lagoon  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     Action  1980
# 3                                          Airplane!     Comedy  1980
# 4                                         Caddyshack     Comedy  1980
# ...                                              ...        ...   ...
# 7663                                    More to Life      Drama  2020
# 7664                                     Dream Round     Comedy  2020
# 7665                                   Saving Mbango      Drama  2020
# 7666                                    It's Just Us      Drama  2020
# 7667                                       Tee em el     Horror  2020
#
#                               released  score      votes         director  \
# ...

# %%
df.head(10)
# Out:
#                                              name      genre  year  \
# 0                                     The Shining      Drama  1980
# 1                                 The Blue Lagoon  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     Action  1980
# 3                                       Airplane!     Comedy  1980
# 4                                      Caddyshack     Comedy  1980
# 5                                 Friday the 13th     Horror  1980
# 6                              The Blues Brothers     Action  1980
# 7                                     Raging Bull  Biography  1980
# 8                                     Superman II     Action  1980
# 9                                 The Long Riders  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# 1       July 2, 1980 (United States)    5.8    65000.0      Randal Kleiser
# ...

# %%
# Let's see if there is missing Data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print(pct_missing)
# Out:
# 0.0
# 0.0
# 0.0
# 0.0002608242044861763
# 0.0003912363067292645
# 0.0003912363067292645
# 0.0
# 0.0003912363067292645
# 0.00013041210224308815
# 0.0003912363067292645
# 0.2831246739697444
# 0.02464788732394366
# 0.002217005738132499
# 0.0005216484089723526

# %%
# let's see The Data types for our columns
df.dtypes
# Out:
# name         object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#change Data type of columns
df = df.fillna(0) # we used fillna fuction because there is some missing values
df['budget'] = df['budget'].astype('int64')
df['votes'] = df['votes'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
df
# Out:
#                                                 name      genre  year  \
# 0                                        The Shining      Drama  1980
# 1                                    The Blue Lagoon  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     Action  1980
# 3                                          Airplane!     Comedy  1980
# 4                                         Caddyshack     Comedy  1980
# ...                                              ...        ...   ...
# 7663                                    More to Life      Drama  2020
# 7664                                     Dream Round     Comedy  2020
# 7665                                   Saving Mbango      Drama  2020
# 7666                                    It's Just Us      Drama  2020
# 7667                                       Tee em el     Horror  2020
#
#                               released  score    votes         director  \
# ...

# %%
# sorting the Data by the values of gross column
df = df.sort_values(by=['gross'], inplace=False, ascending=False)

# %%
# drop any duplicates
df.drop_duplicates()
# Out:
#                                             name    genre  year  \
# 5445                                      Avatar   Action  2009
# 7445                           Avengers: Endgame   Action  2019
# 3045                                     Titanic    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens   Action  2015
# 7244                      Avengers: Infinity War   Action  2018
# ...                                          ...      ...   ...
# 1617                             Mortal Passions    Crime  1989
# 1614                              Edge of Sanity   Horror  1989
# 1606                                   I, Madman  Fantasy  1989
# 1601                        My Twentieth Century   Comedy  1989
# 7667                                   Tee em el   Horror  2020
#
#                                released  score    votes        director  \
# 5445  December 18, 2009 (United States)    7.8  1100000   James Cameron
# ...

# %%
# scatterplot with budget vs gross
plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget VS Gross Earnings')
plt.xlabel('Budget for Film')
plt.ylabel('Gross Earnings')
plt.show()

# %%
# plot budget VS Gross using seaborn
sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color': 'red'}, line_kws={'color': 'blue'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# let's start looking at correlation
df.corr(method='pearson') # there are three methods(pearson, kendall, spearman)
# Out:
#               name     genre      year  released     score     votes  \
# name      1.000000  0.016355  0.011453 -0.011311  0.016377  0.013038
# genre     0.016355  1.000000 -0.081261  0.029822  0.027384 -0.145296
# year      0.011453 -0.081261  1.000000 -0.000695  0.092616  0.222427
# released -0.011311  0.029822 -0.000695  1.000000  0.039814  0.015878
# score     0.016377  0.027384  0.092616  0.039814  1.000000  0.407101
# votes     0.013038 -0.145296  0.222427  0.015878  0.407101  1.000000
# director  0.009079 -0.015258 -0.020795 -0.001478  0.010568  0.000349
# writer    0.009081  0.006567 -0.008656 -0.002404  0.022098  0.001127
# star      0.006472 -0.005477 -0.027242  0.015777 -0.000026 -0.019146
# country  -0.010737 -0.037615 -0.070938 -0.020427 -0.133346  0.073525
# budget    0.020548 -0.334021  0.309212  0.009145  0.056863  0.486931
# gross     0.006989 -0.234297  0.261900  0.000519  0.186012  0.632870
# company   0.009211 -0.071067 -0.010431 -0.010474  0.005081  0.133457
# ...

# %%
correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title('Corelation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category').cat.codes
df_numerized
# Out:
#       name  genre  year  released  score    votes  director  writer  star  \
# 5445   533      0  2009       697    7.8  1100000      1155    1779  2335
# 7445   535      0  2019       184    8.4   903000       162     744  2242
# 3045  6896      6  1997       705    7.8  1100000      1155    1779  1596
# 6663  5144      0  2015       699    7.8   876000      1125    2551   525
# 7244   536      0  2018       193    8.4   897000       162     744  2242
# ...    ...    ...   ...       ...    ...      ...       ...     ...   ...
# 1617  3712      5  1989      1278    4.5      274       117      83  2798
# 1614  1745     10  1989        56    5.2     1300      1033    1744   167
# 1606  2691      8  1989       258    6.0     2900      2743     947  1196
# 1601  3836      4  1989      1161    7.1     1500      1105    1697   682
# 7667  5394     10  2020       392    5.7        7      2165    3345  2464
#
#       country     budget       gross  company  runtime
# ...

# %%
df
# Out:
#       name  genre  year  released  score    votes  director  writer  star  \
# 5445   533      0  2009       697    7.8  1100000      1155    1779  2335
# 7445   535      0  2019       184    8.4   903000       162     744  2242
# 3045  6896      6  1997       705    7.8  1100000      1155    1779  1596
# 6663  5144      0  2015       699    7.8   876000      1125    2551   525
# 7244   536      0  2018       193    8.4   897000       162     744  2242
# ...    ...    ...   ...       ...    ...      ...       ...     ...   ...
# 1617  3712      5  1989      1278    4.5      274       117      83  2798
# 1614  1745     10  1989        56    5.2     1300      1033    1744   167
# 1606  2691      8  1989       258    6.0     2900      2743     947  1196
# 1601  3836      4  1989      1161    7.1     1500      1105    1697   682
# 7667  5394     10  2020       392    5.7        7      2165    3345  2464
#
#       country     budget       gross  company  runtime
# ...

# %%
correlation_matrix = df_numerized.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title('Corelation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
df_numerized.corr()
# Out:
#               name     genre      year  released     score     votes  \
# name      1.000000  0.016355  0.011453 -0.011311  0.016377  0.013038
# genre     0.016355  1.000000 -0.081261  0.029822  0.027384 -0.145296
# year      0.011453 -0.081261  1.000000 -0.000695  0.092616  0.222427
# released -0.011311  0.029822 -0.000695  1.000000  0.039814  0.015878
# score     0.016377  0.027384  0.092616  0.039814  1.000000  0.407101
# votes     0.013038 -0.145296  0.222427  0.015878  0.407101  1.000000
# director  0.009079 -0.015258 -0.020795 -0.001478  0.010568  0.000349
# writer    0.009081  0.006567 -0.008656 -0.002404  0.022098  0.001127
# star      0.006472 -0.005477 -0.027242  0.015777 -0.000026 -0.019146
# country  -0.010737 -0.037615 -0.070938 -0.020427 -0.133346  0.073525
# budget    0.020548 -0.334021  0.309212  0.009145  0.056863  0.486931
# gross     0.006989 -0.234297  0.261900  0.000519  0.186012  0.632870
# company   0.009211 -0.071067 -0.010431 -0.010474  0.005081  0.133457
# ...

# %%
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name     name        1.000000
#          genre       0.016355
#          year        0.011453
#          released   -0.011311
#          score       0.016377
#                        ...
# runtime  country    -0.073319
#          budget      0.268372
#          gross       0.244339
#          company     0.037537
#          runtime     1.000000
# Length: 196, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs.head(50)
# Out:
# budget    genre      -0.334021
# genre     budget     -0.334021
# gross     genre      -0.234297
# genre     gross      -0.234297
#           votes      -0.145296
# votes     genre      -0.145296
# score     country    -0.133346
# country   score      -0.133346
# genre     year       -0.081261
# year      genre      -0.081261
# country   runtime    -0.073319
# runtime   country    -0.073319
# genre     company    -0.071067
# company   genre      -0.071067
# year      country    -0.070938
# country   year       -0.070938
# runtime   genre      -0.052914
# genre     runtime    -0.052914
# country   genre      -0.037615
# genre     country    -0.037615
# year      star       -0.027242
# star      year       -0.027242
# budget    writer     -0.025911
# writer    budget     -0.025911
# gross     writer     -0.022997
# writer    gross      -0.022997
# year      director   -0.020795
# director  year       -0.020795
# released  country    -0.020427
# country   released   -0.020427
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# gross     votes       0.632870
# votes     gross       0.632870
# budget    gross       0.750157
# gross     budget      0.750157
# name      name        1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# director  director    1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64
